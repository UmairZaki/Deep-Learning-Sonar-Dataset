# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras import layers, optimizers

# load dataset
dataframe = pd.read_csv("sonar.csv", header=None)
dataset = dataframe.values


# shuffle data to shuffle rocks & mine data
np.random.shuffle(dataset)

# split into input (X) and output (Y) variables
x = dataset[:,0:60].astype(float)
y = dataset[:,60]

#normaliazing data
x -= x.mean(axis=0)
x /= x.std(axis=0)

#encode label in 1 and 0
a = y.tolist()
b= []
for i in a:
    if i == 'R':
        i = 1
        b.append(i)
    else:
        i = 0
        b.append(i)
y = np.asarray(b)

#split data in test and train
x_test = x[:45]
x_train = x[45:]
y_test = y[:45]
y_train = y[45:]

# build model for k-fold cross validation
def build_model():
    model = Sequential()
    model.add(Dense(60, activation='relu', input_shape=(60,)))
    model.add(Dense(1, activation='sigmoid'))
    sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])
    return model

#K-Fold Cross Validation
k = 4
num_val_samples = len(x_train) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print('processing fold #', i)
    val_data = x_train[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate([x_train[:i * num_val_samples],x_train[(i + 1) * num_val_samples:]],axis=0)
    partial_train_targets = np.concatenate([y_train[:i * num_val_samples],y_train[(i + 1) * num_val_samples:]],axis=0)
    
model = build_model()
model.fit(partial_train_data, partial_train_targets,
epochs=num_epochs, batch_size=1, verbose=1)
val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
all_scores.append(val_mae)
# Out:
# Using TensorFlow backend.
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 123/123 [==============================] - 1s 4ms/step - loss: 0.6760 - accuracy: 0.7154
# Epoch 2/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8780
# Epoch 3/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.8862
# Epoch 4/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9593
# Epoch 5/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9593
# Epoch 6/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9675
# Epoch 7/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 8/100
# 123/123 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 9/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 10/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 11/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 12/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 13/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 14/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 15/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 16/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 17/100
# 123/123 [==============================] - 0s 2ms/step - loss: 9.7697e-04 - accuracy: 1.0000
# Epoch 18/100
# 123/123 [==============================] - 0s 2ms/step - loss: 9.1478e-04 - accuracy: 1.0000
# Epoch 19/100
# 123/123 [==============================] - 0s 2ms/step - loss: 8.5202e-04 - accuracy: 1.0000
# Epoch 20/100
# 123/123 [==============================] - 0s 2ms/step - loss: 7.9925e-04 - accuracy: 1.0000
# Epoch 21/100
# 123/123 [==============================] - 0s 2ms/step - loss: 7.5639e-04 - accuracy: 1.0000
# Epoch 22/100
# 123/123 [==============================] - 0s 2ms/step - loss: 7.1273e-04 - accuracy: 1.0000
# Epoch 23/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.7729e-04 - accuracy: 1.0000
# Epoch 24/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.4411e-04 - accuracy: 1.0000
# Epoch 25/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.1441e-04 - accuracy: 1.0000
# Epoch 26/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.8571e-04 - accuracy: 1.0000
# Epoch 27/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.6118e-04 - accuracy: 1.0000
# Epoch 28/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.3701e-04 - accuracy: 1.0000
# Epoch 29/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.1595e-04 - accuracy: 1.0000
# Epoch 30/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.9717e-04 - accuracy: 1.0000
# Epoch 31/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.7838e-04 - accuracy: 1.0000
# Epoch 32/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.5995e-04 - accuracy: 1.0000
# Epoch 33/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.4432e-04 - accuracy: 1.0000
# Epoch 34/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.3122e-04 - accuracy: 1.0000
# Epoch 35/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.1575e-04 - accuracy: 1.0000
# Epoch 36/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.0195e-04 - accuracy: 1.0000
# Epoch 37/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.9048e-04 - accuracy: 1.0000
# Epoch 38/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.7811e-04 - accuracy: 1.0000
# Epoch 39/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.6779e-04 - accuracy: 1.0000
# Epoch 40/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.5666e-04 - accuracy: 1.0000
# Epoch 41/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.4687e-04 - accuracy: 1.0000
# Epoch 42/100
# 123/123 [==============================] - 0s 3ms/step - loss: 3.3767e-04 - accuracy: 1.0000
# Epoch 43/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.2891e-04 - accuracy: 1.0000
# Epoch 44/100
# 123/123 [==============================] - 0s 3ms/step - loss: 3.2017e-04 - accuracy: 1.0000
# Epoch 45/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.1198e-04 - accuracy: 1.0000
# Epoch 46/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.0465e-04 - accuracy: 1.0000
# Epoch 47/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.9712e-04 - accuracy: 1.0000
# Epoch 48/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.9156e-04 - accuracy: 1.0000
# Epoch 49/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.8361e-04 - accuracy: 1.0000
# Epoch 50/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.7758e-04 - accuracy: 1.0000
# Epoch 51/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.7121e-04 - accuracy: 1.0000
# Epoch 52/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.6556e-04 - accuracy: 1.0000
# Epoch 53/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.6025e-04 - accuracy: 1.0000
# Epoch 54/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.5405e-04 - accuracy: 1.0000
# Epoch 55/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.4952e-04 - accuracy: 1.0000
# Epoch 56/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.4464e-04 - accuracy: 1.0000
# Epoch 57/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.3998e-04 - accuracy: 1.0000
# Epoch 58/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.3458e-04 - accuracy: 1.0000
# Epoch 59/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.3065e-04 - accuracy: 1.0000
# Epoch 60/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.2639e-04 - accuracy: 1.0000
# Epoch 61/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.2256e-04 - accuracy: 1.0000
# Epoch 62/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.1870e-04 - accuracy: 1.0000
# Epoch 63/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.1447e-04 - accuracy: 1.0000
# Epoch 64/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.1081e-04 - accuracy: 1.0000
# Epoch 65/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.0669e-04 - accuracy: 1.0000
# Epoch 66/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.0375e-04 - accuracy: 1.0000
# Epoch 67/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.0004e-04 - accuracy: 1.0000
# Epoch 68/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9720e-04 - accuracy: 1.0000
# Epoch 69/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9380e-04 - accuracy: 1.0000
# Epoch 70/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9071e-04 - accuracy: 1.0000
# Epoch 71/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.8791e-04 - accuracy: 1.0000
# Epoch 72/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.8480e-04 - accuracy: 1.0000
# Epoch 73/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.8192e-04 - accuracy: 1.0000
# Epoch 74/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.7946e-04 - accuracy: 1.0000
# Epoch 75/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.7668e-04 - accuracy: 1.0000
# Epoch 76/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.7432e-04 - accuracy: 1.0000
# Epoch 77/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.7174e-04 - accuracy: 1.0000
# Epoch 78/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6923e-04 - accuracy: 1.0000
# Epoch 79/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6698e-04 - accuracy: 1.0000
# Epoch 80/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6480e-04 - accuracy: 1.0000
# Epoch 81/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6231e-04 - accuracy: 1.0000
# Epoch 82/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6027e-04 - accuracy: 1.0000
# Epoch 83/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5826e-04 - accuracy: 1.0000
# Epoch 84/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5602e-04 - accuracy: 1.0000
# Epoch 85/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5394e-04 - accuracy: 1.0000
# Epoch 86/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5220e-04 - accuracy: 1.0000
# Epoch 87/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5016e-04 - accuracy: 1.0000
# Epoch 88/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4813e-04 - accuracy: 1.0000
# Epoch 89/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4639e-04 - accuracy: 1.0000
# Epoch 90/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4451e-04 - accuracy: 1.0000
# Epoch 91/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4285e-04 - accuracy: 1.0000
# Epoch 92/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4107e-04 - accuracy: 1.0000
# Epoch 93/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3944e-04 - accuracy: 1.0000
# Epoch 94/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3794e-04 - accuracy: 1.0000
# Epoch 95/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3605e-04 - accuracy: 1.0000
# Epoch 96/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3478e-04 - accuracy: 1.0000
# Epoch 97/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3315e-04 - accuracy: 1.0000
# Epoch 98/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3185e-04 - accuracy: 1.0000
# Epoch 99/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3011e-04 - accuracy: 1.0000
# Epoch 100/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.2878e-04 - accuracy: 1.0000
# 40/40 [==============================] - 0s 2ms/step

# %%
print(all_scores)
# Out:
# [0.8500000238418579]

# %%
np.mean(all_scores)
# Out:
# 0.8500000238418579
