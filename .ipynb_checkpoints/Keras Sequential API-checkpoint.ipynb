# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from sklearn.preprocessing import LabelEncoder

# load dataset
dataframe = pd.read_csv("sonar.csv", header=None)
dataset = dataframe.values 

# shuffle data for shaffling rocks and mine
np.random.shuffle(dataset)

# split into input (X) and output (Y) variables
x = dataset[:,0:60].astype(float)
y = dataset[:,60]

#normaliazing data
x -= x.mean(axis=0)
x /= x.std(axis=0)

#encode label in 1 and 0
encoder = LabelEncoder()
encoder.fit(y)
y = encoder.transform(y)

# split data test and train
x_test = x[:45]
x_train = x[45:]
y_test = y[:45]
y_train = y[45:]

# split train data in partial tran and validation
x_val = x_train[:45]
partial_x_train = x_train[45:]
y_val = y_train[:45]
partial_y_train = y_train[45:]

#Keras Sequential API
model = Sequential()
model.add(Dense(60, activation='relu', input_shape=(60,)))
model.add(Dense(1, activation='sigmoid'))
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(partial_x_train,partial_y_train,epochs=100,batch_size=5,validation_data=(x_val, y_val))
# Out:
# Using TensorFlow backend.
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 118 samples, validate on 45 samples
# Epoch 1/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.6192 - accuracy: 0.6695 - val_loss: 0.6016 - val_accuracy: 0.6444
# Epoch 2/100
# 118/118 [==============================] - 0s 879us/step - loss: 0.3555 - accuracy: 0.8136 - val_loss: 0.4829 - val_accuracy: 0.7333
# Epoch 3/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2196 - accuracy: 0.9237 - val_loss: 0.4690 - val_accuracy: 0.7778
# Epoch 4/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1525 - accuracy: 0.9661 - val_loss: 0.4329 - val_accuracy: 0.7556
# Epoch 5/100
# 118/118 [==============================] - 0s 992us/step - loss: 0.1103 - accuracy: 0.9915 - val_loss: 0.4232 - val_accuracy: 0.8000
# Epoch 6/100
# 118/118 [==============================] - 0s 963us/step - loss: 0.0857 - accuracy: 0.9915 - val_loss: 0.4151 - val_accuracy: 0.8000
# Epoch 7/100
# 118/118 [==============================] - 0s 823us/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.4152 - val_accuracy: 0.8000
# Epoch 8/100
# 118/118 [==============================] - 0s 926us/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.4005 - val_accuracy: 0.8222
# Epoch 9/100
# 118/118 [==============================] - 0s 828us/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.4102 - val_accuracy: 0.8222
# Epoch 10/100
# 118/118 [==============================] - 0s 846us/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.8000
# Epoch 11/100
# 118/118 [==============================] - 0s 844us/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.4017 - val_accuracy: 0.8222
# Epoch 12/100
# 118/118 [==============================] - 0s 861us/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.4102 - val_accuracy: 0.8222
# Epoch 13/100
# 118/118 [==============================] - 0s 887us/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.4131 - val_accuracy: 0.8444
# Epoch 14/100
# 118/118 [==============================] - 0s 971us/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.8222
# Epoch 15/100
# 118/118 [==============================] - 0s 960us/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.4063 - val_accuracy: 0.8222
# Epoch 16/100
# 118/118 [==============================] - 0s 924us/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.8222
# Epoch 17/100
# 118/118 [==============================] - 0s 903us/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.8222
# Epoch 18/100
# 118/118 [==============================] - 0s 796us/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.4249 - val_accuracy: 0.8222
# Epoch 19/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.8222
# Epoch 20/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4261 - val_accuracy: 0.8444
# Epoch 21/100
# 118/118 [==============================] - 0s 762us/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.8444
# Epoch 22/100
# 118/118 [==============================] - 0s 804us/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0
/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8667
# Epoch 62/100
# 118/118 [==============================] - 0s 689us/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4912 - val_accuracy: 0.8667
# Epoch 63/100
# 118/118 [==============================] - 0s 860us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.8667
# Epoch 64/100
# 118/118 [==============================] - 0s 758us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8667
# Epoch 65/100
# 118/118 [==============================] - 0s 772us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8667
# Epoch 66/100
# 118/118 [==============================] - 0s 771us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.8667
# Epoch 67/100
# 118/118 [==============================] - 0s 733us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.8667
# Epoch 68/100
# 118/118 [==============================] - 0s 748us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4971 - val_accuracy: 0.8667
# Epoch 69/100
# 118/118 [==============================] - 0s 759us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.8667
# Epoch 70/100
# 118/118 [==============================] - 0s 820us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4992 - val_accuracy: 0.8667
# Epoch 71/100
# 118/118 [==============================] - 0s 727us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.8667
# Epoch 72/100
# 118/118 [==============================] - 0s 784us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.8667
# Epoch 73/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.8667
# Epoch 74/100
# 118/118 [==============================] - 0s 811us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5020 - val_accuracy: 0.8667
# Epoch 75/100
# 118/118 [==============================] - 0s 813us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.8667
# Epoch 76/100
# 118/118 [==============================] - 0s 835us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.8667
# Epoch 77/100
# 118/118 [==============================] - 0s 721us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8667
# Epoch 78/100
# 118/118 [==============================] - 0s 762us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8667
# Epoch 79/100
# 118/118 [==============================] - 0s 741us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5060 - val_accuracy: 0.8667
# Epoch 80/100
# 118/118 [==============================] - 0s 785us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8667
# Epoch 81/100
# 118/118 [==============================] - 0s 820us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8667
# Epoch 82/100
# 118/118 [==============================] - 0s 763us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.8667
# Epoch 83/100
# 118/118 [==============================] - 0s 866us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.8667
# Epoch 84/100
# 118/118 [==============================] - 0s 834us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5102 - val_accuracy: 0.8667
# Epoch 85/100
# 118/118 [==============================] - 0s 698us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.8667
# Epoch 86/100
# 118/118 [==============================] - 0s 764us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.8667
# Epoch 87/100
# 118/118 [==============================] - 0s 755us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8667
# Epoch 88/100
# 118/118 [==============================] - 0s 724us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.8667
# Epoch 89/100
# 118/118 [==============================] - 0s 793us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.8667
# Epoch 90/100
# 118/118 [==============================] - 0s 783us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8667
# Epoch 91/100
# 118/118 [==============================] - 0s 784us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8667
# Epoch 92/100
# 118/118 [==============================] - 0s 774us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8667
# Epoch 93/100
# 118/118 [==============================] - 0s 729us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.8667
# Epoch 94/100
# 118/118 [==============================] - 0s 796us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.8667
# Epoch 95/100
# 118/118 [==============================] - 0s 782us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.8667
# Epoch 96/100
# 118/118 [==============================] - 0s 777us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.8667
# Epoch 97/100
# 118/118 [==============================] - 0s 754us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5197 - val_accuracy: 0.8667
# Epoch 98/100
# 118/118 [==============================] - 0s 767us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5200 - val_accuracy: 0.8667
# Epoch 99/100
# 118/118 [==============================] - 0s 761us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.8667
# Epoch 100/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.8667

# %%
#evaluate on test data
results = model.evaluate(x_test, y_test)
print(results)
# Out:
# 45/45 [==============================] - 2s 45ms/step
# [0.3265004918393162, 0.8444444537162781]
