# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras import layers, optimizers
from sklearn.preprocessing import LabelEncoder

# load dataset
dataframe = pd.read_csv("sonar.csv", header=None)
dataset = dataframe.values


# shuffle data to shuffle rocks & mine data
np.random.shuffle(dataset)

# split into input (X) and output (Y) variables
x = dataset[:,0:60].astype(float)
y = dataset[:,60]

#normaliazing data
x -= x.mean(axis=0)
x /= x.std(axis=0)

#encode label in 1 and 0
encoder = LabelEncoder()
encoder.fit(y)
y = encoder.transform(y)

#split data in test and train
x_test = x[:45]
x_train = x[45:]
y_test = y[:45]
y_train = y[45:]

# build model for k-fold cross validation
def build_model():
    model = Sequential()
    model.add(Dense(60, activation='relu', input_shape=(60,)))
    model.add(Dense(1, activation='sigmoid'))
    sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])
    return model

#K-Fold Cross Validation
k = 4
num_val_samples = len(x_train) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print('processing fold #', i)
    val_data = x_train[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate([x_train[:i * num_val_samples],x_train[(i + 1) * num_val_samples:]],axis=0)
    partial_train_targets = np.concatenate([y_train[:i * num_val_samples],y_train[(i + 1) * num_val_samples:]],axis=0)
    
model = build_model()
model.fit(partial_train_data, partial_train_targets,
epochs=num_epochs, batch_size=1, verbose=1)
val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
all_scores.append(val_mae)
# Out:
# Using TensorFlow backend.
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/umair/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/umair/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 123/123 [==============================] - 1s 9ms/step - loss: 0.6162 - accuracy: 0.7317
# Epoch 2/100
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3243 - accuracy: 0.8862
# Epoch 3/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.9268
# Epoch 4/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9919
# Epoch 5/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 6/100
# 123/123 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 7/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 8/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 9/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 10/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 11/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 12/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 13/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 14/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 15/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 16/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 17/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 18/100
# 123/123 [==============================] - 0s 3ms/step - loss: 9.7034e-04 - accuracy: 1.0000
# Epoch 19/100
# 123/123 [==============================] - 0s 2ms/step - loss: 9.0158e-04 - accuracy: 1.0000
# Epoch 20/100
# 123/123 [==============================] - 0s 2ms/step - loss: 8.5704e-04 - accuracy: 1.0000
# Epoch 21/100
# 123/123 [==============================] - 0s 2ms/step - loss: 8.0534e-04 - accuracy: 1.0000
# Epoch 22/100
# 123/123 [==============================] - 0s 3ms/step - loss: 7.6282e-04 - accuracy: 1.0000
# Epoch 23/100
# 123/123 [==============================] - 0s 2ms/step - loss: 7.1875e-04 - accuracy: 1.0000
# Epoch 24/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.8783e-04 - accuracy: 1.0000
# Epoch 25/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.5365e-04 - accuracy: 1.0000
# Epoch 26/100
# 123/123 [==============================] - 0s 2ms/step - loss: 6.2598e-04 - accuracy: 1.0000
# Epoch 27/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.9760e-04 - accuracy: 1.0000
# Epoch 28/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.7084e-04 - accuracy: 1.0000
# Epoch 29/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.5064e-04 - accuracy: 1.0000
# Epoch 30/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.2691e-04 - accuracy: 1.0000
# Epoch 31/100
# 123/123 [==============================] - 0s 2ms/step - loss: 5.0754e-04 - accuracy: 1.0000
# Epoch 32/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.8922e-04 - accuracy: 1.0000
# Epoch 33/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.7251e-04 - accuracy: 1.0000
# Epoch 34/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.5454e-04 - accuracy: 1.0000
# Epoch 35/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.4287e-04 - accuracy: 1.0000
# Epoch 36/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.2715e-04 - accuracy: 1.0000
# Epoch 37/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.1305e-04 - accuracy: 1.0000
# Epoch 38/100
# 123/123 [==============================] - 0s 2ms/step - loss: 4.0133e-04 - accuracy: 1.0000
# Epoch 39/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.9086e-04 - accuracy: 1.0000
# Epoch 40/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.7866e-04 - accuracy: 1.0000
# Epoch 41/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.6760e-04 - accuracy: 1.0000
# Epoch 42/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.5768e-04 - accuracy: 1.0000
# Epoch 43/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.4763e-04 - accuracy: 1.0000
# Epoch 44/100
# 123/123 [==============================] - 0s 3ms/step - loss: 3.3859e-04 - accuracy: 1.0000
# Epoch 45/100
# 123/123 [==============================] - 0s 3ms/step - loss: 3.3110e-04 - accuracy: 1.0000
# Epoch 46/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.2302e-04 - accuracy: 1.0000
# Epoch 47/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.1494e-04 - accuracy: 1.0000
# Epoch 48/100
# 123/123 [==============================] - 0s 2ms/step - loss: 3.0749e-04 - accuracy: 1.0000
# Epoch 49/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.9985e-04 - accuracy: 1.0000
# Epoch 50/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.9421e-04 - accuracy: 1.0000
# Epoch 51/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.8748e-04 - accuracy: 1.0000
# Epoch 52/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.8124e-04 - accuracy: 1.0000
# Epoch 53/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.7515e-04 - accuracy: 1.0000
# Epoch 54/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.6882e-04 - accuracy: 1.0000
# Epoch 55/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.6358e-04 - accuracy: 1.0000
# Epoch 56/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.5729e-04 - accuracy: 1.0000
# Epoch 57/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.5318e-04 - accuracy: 1.0000
# Epoch 58/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.4823e-04 - accuracy: 1.0000
# Epoch 59/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.4270e-04 - accuracy: 1.0000
# Epoch 60/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.3894e-04 - accuracy: 1.0000
# Epoch 61/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.3440e-04 - accuracy: 1.0000
# Epoch 62/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.3002e-04 - accuracy: 1.0000
# Epoch 63/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.2542e-04 - accuracy: 1.0000
# Epoch 64/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.2219e-04 - accuracy: 1.0000
# Epoch 65/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.1839e-04 - accuracy: 1.0000
# Epoch 66/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.1462e-04 - accuracy: 1.0000
# Epoch 67/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.1057e-04 - accuracy: 1.0000
# Epoch 68/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.0756e-04 - accuracy: 1.0000
# Epoch 69/100
# 123/123 [==============================] - 0s 3ms/step - loss: 2.0405e-04 - accuracy: 1.0000
# Epoch 70/100
# 123/123 [==============================] - 0s 2ms/step - loss: 2.0081e-04 - accuracy: 1.0000
# Epoch 71/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9793e-04 - accuracy: 1.0000
# Epoch 72/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9484e-04 - accuracy: 1.0000
# Epoch 73/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.9167e-04 - accuracy: 1.0000
# Epoch 74/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.8847e-04 - accuracy: 1.0000
# Epoch 75/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.8573e-04 - accuracy: 1.0000
# Epoch 76/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.8312e-04 - accuracy: 1.0000
# Epoch 77/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.8062e-04 - accuracy: 1.0000
# Epoch 78/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.7797e-04 - accuracy: 1.0000
# Epoch 79/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.7546e-04 - accuracy: 1.0000
# Epoch 80/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.7297e-04 - accuracy: 1.0000
# Epoch 81/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.7042e-04 - accuracy: 1.0000
# Epoch 82/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6853e-04 - accuracy: 1.0000
# Epoch 83/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6592e-04 - accuracy: 1.0000
# Epoch 84/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6391e-04 - accuracy: 1.0000
# Epoch 85/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.6174e-04 - accuracy: 1.0000
# Epoch 86/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5957e-04 - accuracy: 1.0000
# Epoch 87/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5771e-04 - accuracy: 1.0000
# Epoch 88/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.5562e-04 - accuracy: 1.0000
# Epoch 89/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.5384e-04 - accuracy: 1.0000
# Epoch 90/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.5174e-04 - accuracy: 1.0000
# Epoch 91/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.4975e-04 - accuracy: 1.0000
# Epoch 92/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.4809e-04 - accuracy: 1.0000
# Epoch 93/100
# 123/123 [==============================] - 0s 3ms/step - loss: 1.4633e-04 - accuracy: 1.0000
# Epoch 94/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4459e-04 - accuracy: 1.0000
# Epoch 95/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4288e-04 - accuracy: 1.0000
# Epoch 96/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.4121e-04 - accuracy: 1.0000
# Epoch 97/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3937e-04 - accuracy: 1.0000
# Epoch 98/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3805e-04 - accuracy: 1.0000
# Epoch 99/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3644e-04 - accuracy: 1.0000
# Epoch 100/100
# 123/123 [==============================] - 0s 2ms/step - loss: 1.3492e-04 - accuracy: 1.0000
# 40/40 [==============================] - 0s 4ms/step

# %%
print(all_scores)
# Out:
# [0.8999999761581421]

# %%
np.mean(all_scores)
# Out:
# 0.8999999761581421
